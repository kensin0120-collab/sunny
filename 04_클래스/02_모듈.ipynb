# %%
from mod1 import add, sub

print(add(7, 10))
print(sub(10, 3))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from mod1 import add, sub
#       3 print(add(7, 10))
#       4 print(sub(10, 3))
#
# ImportError: cannot import name 'add' from 'mod1' (c:\Users\NT371B5A\Documents\bigdate\04_클래스\mod1.py)

# %%
from mod1 import *

print(add(10, 10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from mod1 import *
# ----> 3 print(add(10, 10))
#
# NameError: name 'add' is not defined

# %%
from mod1 import add 

add(3,4)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from mod1 import add
#       3 add(3,4)
#
# ImportError: cannot import name 'add' from 'mod1' (c:\Users\NT371B5A\Documents\bigdate\04_클래스\mod1.py)
