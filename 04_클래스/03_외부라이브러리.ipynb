# %%
# pip install
# !pip install SomePackage

# %%
# pip install 패키지명 -> 설치
# pip uninstall 패키지명 -> 삭제
# pip install 패키지명==버전 -> 특정버전을 설치
# pip list -> 설치된 패키지 리스트 확인

# %%
# !pip install Faker

# %%
# from faker import Faker
import faker

# fake = Faker()
# fake.name()
# fake.address()

# for _ in range(10):
#     print(fake.name())

a = faker.Faker()
a.name()
# Out:
# 'Michelle Holt'
