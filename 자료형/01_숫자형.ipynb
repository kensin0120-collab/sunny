# %%
1+1
# Out:
# 2

# %%
#사칙연산
a = 3
b = 4
print(a+b)
print(a-b)
# Out:
# 7
# -1

# %%
# x의 y제곱을 나타내는 ** 연산자
a = 3

# %%
#나눗셈 후 나머지를 구하는 % 연산자
print(7%3)
print(3%2)
# Out:
# 1
# 1

# %%
#나눗셈 후 몫을 구하는 연산자
print(7//4)
# Out:
# 1

# %%
#복합연산자
a = 1
a += 1
# a = a + 1
# +=
# -=
print(a)
# Out:
# 2
