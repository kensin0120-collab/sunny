# %%
#튜플은 어떻게 만들까?
t1 = ()
t2 = (1, ) #하나를 쓸 때는 콤마 넣어 줘야 함
t3 = (1, 2, 3)
t4 = 1, 2, 3 #괄호가 생략된 튜플로 인식
t5 = ("a", "b", ("ab", "cd"))

# a = 1,
# b = 2
# c = [1, 2, 3]
# d = (1, 2)

# %%
t1 = (1, 2, "a", "b")
del
#튜플 요소값을 삭제하려 할 때 -> 지울 수 없음
# Out:
#   Cell In[3], line 2
#     del
#        ^
# SyntaxError: invalid syntax

# %%
t1 = (1, 2, "a", "b")

#튜플 요소값을 변경하려 할 때 -> 변경 할 수 없음
t1[1] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 t1 = (1, 2, "a", "b")
#       3 #튜플 요소값을 변경하려 할 때 -> 변경 할 수 없음
# ----> 4 t1[1] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 인덱싱 하기
t1 = (1, 2, "a", "b")
t1[2]
# Out:
# 'a'

# %%
#슬라이싱하기
t1 = (1, 2, "a", "b")
t1[2:4]
# Out:
# ('a', 'b')

# %%
#튜플 더하기
t1 = (1, 2, "a", "b")
t2 = (3, 4)
t1 + t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
#튜플 곱하기
t2 = (3, 4)
t2*3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
#튜플에 길이 구하기
t1 = (1, 2, "a", "b")
len(t1)
# Out:
# 4
