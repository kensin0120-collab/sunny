# %%
#변수는 어떻게 만들까?

a = 1
b = "python"
c = [1, 2, 3]

# %%
#변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.
a1 = 1
t1 = 2
type_script = 1
# type-script = 1 마이너스는 안 됨
typeScript = 1
TypeScript = 1

#2. 숫자로 시작할 수 없다.
t1 = 1
# 1t = 1 불가능

#3. 예약어는 사용할 수 없다.
# print
# len
# False
# True
# 등등 파이썬에서 기능을 가지고 있는 건 안 됨

#4. 대소문자를 구분한다.
Abc = 1
abc = 2

print(Abc)
print(abc)
# Out:
# 1
# 2

# %%
a, b = "python", 'Life'
print(a)
print(b)
# Out:
# python
# Life

# %%
[a, b] = ["python", 'Life']
print(a)
print(b)
# Out:
# python
# Life
